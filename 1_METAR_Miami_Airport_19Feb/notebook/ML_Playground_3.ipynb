# %% [markdown]
# #### ML_Playground 3

# %%
## General Import
import numpy as np
import matplotlib.pyplot as plt
import pickle
import pandas as pd
import sys
# Out:
# /tmp/ipykernel_485178/3330568686.py:5: DeprecationWarning:
# Pyarrow will become a required dependency of pandas in the next major release of pandas (pandas 3.0),
# (to allow more performant data types, such as the Arrow string type, and better interoperability with other libraries)
# but was not found to be installed on your system.
# If this would cause problems for you,
# please provide us feedback at https://github.com/pandas-dev/pandas/issues/54466
#
#   import pandas as pd

# %%
### Local Import
package_path = '/home/Lakehouse/DreamBrookPy'
if package_path not in sys.path:
    sys.path.append(package_path)
import DreamBrookPy.MachineLearning as ML
import DreamBrookPy.DataChef as DC
# Out:
# 2024-02-17 00:12:53.818680: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
## Development Code

def savedict(file_path, dict_name):
    """Save dictionary dict_name to file_path"""
    with open(file_path, 'wb') as file:
        pickle.dump(dict_name, file)
        print(f"The data dictionary has been saved to {file_path}.")

# %%
filepath = '../results/Full_Cleaned_METAR_dict.pkl' 
with open(filepath, 'rb') as file:
    raw_METAR_data = pickle.load(file)

# %%
raw_METAR_data.keys()
# Out:
# dict_keys(['year', 'month', 'day', 'hour', 'minute', 'wind_speed', 'wind_direction', 'wind_gust', 'wind_degrees', 'wind_unit', 'wind_min_ver', 'wind_max_var', 'visibility_distance', 'visibility_min_dis', 'visibility_min_dir', 'clouds', 'n_cloud_layers', 'clouds_0_layer', 'clouds_1_layer', 'clouds_2_layer', 'clouds_3_layer', 'clouds_4_layer', 'clouds_5_layer', 'clouds_6_layer', 'temperature', 'dew', 'air_pressure'])

# %% [markdown]
# ## 1.Wind

# %%
wind_degree_data = raw_METAR_data['wind_degrees']

# %%
wind_speed_data = raw_METAR_data['wind_speed']

# %%
### Everything is here in 1 Cell to avoid confusions. Later will automate this for batch processing.
raw_data = wind_degree_data 
Wind_Degree_Results = {} # Container for finalized data
param_list_1 = [6,12,24]
param_list_2 = [8,16,32]
param_list_3 = [2,3,4]
param_list_4 = [0.1,0.2,0.3]
param_list_5 = [50,80]
data_id = 'set1'
datadir = f'../results/wind/wind_degree_{data_id}'

for p1 in param_list_1:
    for p2 in param_list_2:
        for p3 in param_list_3:
            for p4 in param_list_4:
                for p5 in param_list_5:
                    print(f'>>> Starting Training for param :')
                    print(f'window: {p1}')
                    print(f'batch_size: {p2}')
                    print(f'LSTM_depth: {p3}')
                    print(f'Dropout_rate: {p4}')
                    print(f'N_unit: {p5}')
                    
                    # Specify Hyperparameters, and perform training/predictions
                    hyperparameters = {
                        'n_units' : p5,'dropout_rate' : p4, 'n_dense' : 1,
                        'n_epochs' : 100,'n_batch' : p2,'LSTM_depth' : p3,
                        'n_train' :1000,'n_test' : 200,
                        'window_size':p1, 'scaling':'MinMax'
                    }
                    r = ML.process_training_data_and_learn(raw_data, hyperparameters)
                    ##Save_result
                    file_path  = f'{datadir}_w{p1}_b{p2}_d{p3}_rate{p4}_unit{p5}.pkl' 
                    savedict(file_path, dict_name=r)
                    new_data = {f'{datadir}_w{p1}_b{p2}_d{p3}_rate{p4}_unit{p5}':r} 
                
                    ### Provide Data Container
                    Wind_Degree_Results.update(new_data)
# Out:
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 50
# Epoch 1: loss = 0.10284452885389328, duration = 8.65 seconds
# Epoch 11: loss = 0.06425462663173676, duration = 1.18 seconds
# Epoch 21: loss = 0.06204238161444664, duration = 0.76 seconds
# Epoch 31: loss = 0.06319259852170944, duration = 1.00 seconds
# Epoch 41: loss = 0.0641499012708664, duration = 0.99 seconds
# Epoch 51: loss = 0.06208283081650734, duration = 1.00 seconds
# Epoch 61: loss = 0.060819439589977264, duration = 1.05 seconds
# Epoch 71: loss = 0.061568208038806915, duration = 1.05 seconds
# Epoch 81: loss = 0.06133792921900749, duration = 0.91 seconds
# Epoch 91: loss = 0.060289546847343445, duration = 1.01 seconds
# 7/7 [==============================] - 2s 5ms/step
# The root mean squared error is 71.02345843974483.
# The data dictionary has been saved to ../results/wind/wind_degree_set1_w6_b8_d2_rate0.1_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 80
# Epoch 1: loss = 0.09644447267055511, duration = 8.51 seconds
# Epoch 11: loss = 0.06460916250944138, duration = 1.35 seconds
# Epoch 21: loss = 0.0653279572725296, duration = 1.14 seconds
# Epoch 31: loss = 0.06260540336370468, duration = 1.26 seconds
# Epoch 41: loss = 0.06210678815841675, duration = 0.98 seconds
# Epoch 51: loss = 0.06129602715373039, duration = 1.17 seconds
# Epoch 61: loss = 0.06052935868501663, duration = 1.07 seconds
# Epoch 71: loss = 0.06098777428269386, duration = 1.16 seconds
# Epoch 81: loss = 0.05793094262480736, duration = 1.24 seconds
# Epoch 91: loss = 0.05607482045888901, duration = 1.07 seconds
# 7/7 [==============================] - 1s 4ms/step
# The root mean squared error is 72.27788288763168.
# The data dictionary has been saved to ../results/wind/wind_degree_set1_w6_b8_d2_rate0.1_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.2
# N_unit: 50
# Epoch 1: loss = 0.11030199378728867, duration = 7.43 seconds
# Epoch 11: loss = 0.06658181548118591, duration = 1.03 seconds
# Epoch 21: loss = 0.06552150845527649, duration = 0.93 seconds
# Epoch 31: loss = 0.06578002870082855, duration = 1.17 seconds
# Epoch 41: loss = 0.06372787058353424, duration = 1.20 seconds
# Epoch 51: loss = 0.06419204920530319, duration = 1.00 seconds
# Epoch 61: loss = 0.06308368593454361, duration = 1.18 seconds
# Epoch 71: loss = 0.06227945536375046, duration = 0.89 seconds
# Epoch 81: loss = 0.0629391148686409, duration = 1.13 seconds
# Epoch 91: loss = 0.06028604879975319, duration = 0.98 seconds
# 7/7 [==============================] - 2s 11ms/step
# The root mean squared error is 69.35404244053579.
# The data dictionary has been saved to ../results/wind/wind_degree_set1_w6_b8_d2_rate0.2_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.2
# N_unit: 80

# %%
## Wind Speed

# %%
# Out:
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 50
# Epoch 1: loss = 0.046800222247838974, duration = 5.75 seconds
# Epoch 11: loss = 0.022943563759326935, duration = 1.12 seconds
# Epoch 21: loss = 0.022019116207957268, duration = 0.89 seconds
# Epoch 31: loss = 0.020759090781211853, duration = 0.92 seconds
# Epoch 41: loss = 0.02102595381438732, duration = 1.03 seconds
# Epoch 51: loss = 0.02100054919719696, duration = 0.83 seconds
# Epoch 61: loss = 0.021443530917167664, duration = 0.93 seconds
# Epoch 71: loss = 0.021141400560736656, duration = 0.69 seconds
# Epoch 81: loss = 0.020351765677332878, duration = 0.83 seconds
# Epoch 91: loss = 0.020676299929618835, duration = 0.77 seconds
# 7/7 [==============================] - 1s 3ms/step
# The root mean squared error is 2.2339379206942054.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d2_rate0.1_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 80
# Epoch 1: loss = 0.04612346738576889, duration = 6.05 seconds
# Epoch 11: loss = 0.021738369017839432, duration = 1.17 seconds
# Epoch 21: loss = 0.022576048970222473, duration = 1.04 seconds
# Epoch 31: loss = 0.02113167941570282, duration = 0.93 seconds
# Epoch 41: loss = 0.02128695882856846, duration = 1.11 seconds
# Epoch 51: loss = 0.020970942452549934, duration = 1.01 seconds
# Epoch 61: loss = 0.020721886307001114, duration = 1.18 seconds
# Epoch 71: loss = 0.020943449810147285, duration = 1.05 seconds
# Epoch 81: loss = 0.02013462968170643, duration = 0.88 seconds
# Epoch 91: loss = 0.01999599114060402, duration = 1.17 seconds
# 7/7 [==============================] - 1s 3ms/step
# The root mean squared error is 2.3442848770856486.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d2_rate0.1_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.2
# N_unit: 50
# Epoch 1: loss = 0.04699776694178581, duration = 6.43 seconds
# Epoch 11: loss = 0.02372443862259388, duration = 1.07 seconds
# Epoch 21: loss = 0.022625062614679337, duration = 1.03 seconds
# Epoch 31: loss = 0.02231927216053009, duration = 0.84 seconds
# Epoch 41: loss = 0.022363848984241486, duration = 0.95 seconds
# Epoch 51: loss = 0.021954497322440147, duration = 0.93 seconds
# Epoch 61: loss = 0.021379349753260612, duration = 0.96 seconds
# Epoch 71: loss = 0.021130962297320366, duration = 0.85 seconds
# Epoch 81: loss = 0.021214481443166733, duration = 0.92 seconds
# Epoch 91: loss = 0.020665492862462997, duration = 0.91 seconds
# 7/7 [==============================] - 1s 3ms/step
# The root mean squared error is 2.192938998988332.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d2_rate0.2_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.2
# N_unit: 80
# Epoch 1: loss = 0.04632207006216049, duration = 5.86 seconds
# Epoch 11: loss = 0.022953538224101067, duration = 0.91 seconds
# Epoch 21: loss = 0.02238108031451702, duration = 1.13 seconds
# Epoch 31: loss = 0.02199378050863743, duration = 1.04 seconds
# Epoch 41: loss = 0.021603135392069817, duration = 1.10 seconds
# Epoch 51: loss = 0.02100362628698349, duration = 1.21 seconds
# Epoch 61: loss = 0.02083412930369377, duration = 1.17 seconds
# Epoch 71: loss = 0.020765043795108795, duration = 1.12 seconds
# Epoch 81: loss = 0.021153496578335762, duration = 0.93 seconds
# Epoch 91: loss = 0.020653890445828438, duration = 1.15 seconds
# 7/7 [==============================] - 2s 11ms/step
# The root mean squared error is 2.2290819589072557.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d2_rate0.2_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.3
# N_unit: 50
# Epoch 1: loss = 0.052102793008089066, duration = 5.65 seconds
# Epoch 11: loss = 0.023244883865118027, duration = 1.03 seconds
# Epoch 21: loss = 0.021893920376896858, duration = 0.84 seconds
# Epoch 31: loss = 0.021891040727496147, duration = 1.02 seconds
# Epoch 41: loss = 0.022590719163417816, duration = 0.96 seconds
# Epoch 51: loss = 0.02223869040608406, duration = 1.23 seconds
# Epoch 61: loss = 0.020949188619852066, duration = 0.91 seconds
# Epoch 71: loss = 0.0215452890843153, duration = 0.87 seconds
# Epoch 81: loss = 0.021706951782107353, duration = 0.80 seconds
# Epoch 91: loss = 0.02068156935274601, duration = 0.97 seconds
# 7/7 [==============================] - 1s 6ms/step
# The root mean squared error is 2.2218287161071033.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d2_rate0.3_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.3
# N_unit: 80
# Epoch 1: loss = 0.04762392118573189, duration = 5.28 seconds
# Epoch 11: loss = 0.024026991799473763, duration = 2.23 seconds
# Epoch 21: loss = 0.022148411720991135, duration = 2.10 seconds
# Epoch 31: loss = 0.02234191820025444, duration = 1.24 seconds
# Epoch 41: loss = 0.0217972993850708, duration = 0.96 seconds
# Epoch 51: loss = 0.022123659029603004, duration = 1.41 seconds
# Epoch 61: loss = 0.021434906870126724, duration = 1.23 seconds
# Epoch 71: loss = 0.02178327925503254, duration = 1.18 seconds
# Epoch 81: loss = 0.020994089543819427, duration = 1.31 seconds
# Epoch 91: loss = 0.021355388686060905, duration = 1.24 seconds
# 7/7 [==============================] - 1s 5ms/step
# The root mean squared error is 2.3354143643224914.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d2_rate0.3_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.1
# N_unit: 50
# Epoch 1: loss = 0.053554996848106384, duration = 7.58 seconds
# Epoch 11: loss = 0.022657662630081177, duration = 1.22 seconds
# Epoch 21: loss = 0.02217101864516735, duration = 1.65 seconds
# Epoch 31: loss = 0.021522652357816696, duration = 1.36 seconds
# Epoch 41: loss = 0.02209308370947838, duration = 1.26 seconds
# Epoch 51: loss = 0.020574163645505905, duration = 1.47 seconds
# Epoch 61: loss = 0.020828235894441605, duration = 1.26 seconds
# Epoch 71: loss = 0.02098015509545803, duration = 1.31 seconds
# Epoch 81: loss = 0.020935285836458206, duration = 1.23 seconds
# Epoch 91: loss = 0.020597320050001144, duration = 1.36 seconds
# 7/7 [==============================] - 1s 8ms/step
# The root mean squared error is 2.3220883062115907.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d3_rate0.1_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.1
# N_unit: 80
# Epoch 1: loss = 0.05041396617889404, duration = 7.97 seconds
# Epoch 11: loss = 0.022111229598522186, duration = 1.61 seconds
# Epoch 21: loss = 0.021629052236676216, duration = 1.37 seconds
# Epoch 31: loss = 0.021629799157381058, duration = 1.56 seconds
# Epoch 41: loss = 0.0209127776324749, duration = 1.38 seconds
# Epoch 51: loss = 0.020695213228464127, duration = 1.52 seconds
# Epoch 61: loss = 0.020724857226014137, duration = 1.50 seconds
# Epoch 71: loss = 0.02064591832458973, duration = 1.41 seconds
# Epoch 81: loss = 0.020505979657173157, duration = 1.53 seconds
# Epoch 91: loss = 0.019392842426896095, duration = 1.46 seconds
# 7/7 [==============================] - 1s 5ms/step
# The root mean squared error is 2.3299548944926096.
# The data dictionary has been saved to ../results/wind/wind_speed_set1_w6_b8_d3_rate0.1_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.2
# N_unit: 50
# Epoch 1: loss = 0.05346601456403732, duration = 7.68 seconds
# Epoch 11: loss = 0.024199794977903366, duration = 1.14 seconds
# Epoch 21: loss = 0.022375833243131638, duration = 1.11 seconds

# %% [markdown]
# # 2.Cloud

# %% [markdown]
# # 3.Temperature

# %%
temperature_data = raw_METAR_data['temperature']

# %%
### Everything is here in 1 Cell to avoid confusions. Later will automate this for batch processing.
raw_data =temperature_data 
Temperature_Results = {} # Container for finalized data
param_list_1 = [6,12,24]
param_list_2 = [8,16,32]
param_list_3 = [2,3,4]
param_list_4 = [0.1,0.2,0.3]
param_list_5 = [50,80]
data_id = 'set1'
datadir = f'../results/temperature/temperature_{data_id}'

### NO Changes down Here ###
for p1 in param_list_1:
    for p2 in param_list_2:
        for p3 in param_list_3:
            for p4 in param_list_4:
                for p5 in param_list_5:
                    print(f'>>> Starting Training for param :')
                    print(f'window: {p1}')
                    print(f'batch_size: {p2}')
                    print(f'LSTM_depth: {p3}')
                    print(f'Dropout_rate: {p4}')
                    print(f'N_unit: {p5}')
                    
                    # Specify Hyperparameters, and perform training/predictions
                    hyperparameters = {
                        'n_units' : p5,'dropout_rate' : p4, 'n_dense' : 1,
                        'n_epochs' : 100,'n_batch' : p2,'LSTM_depth' : p3,
                        'n_train' :1000,'n_test' : 200,
                        'window_size':p1, 'scaling':'MinMax'
                    }
                    r = ML.process_training_data_and_learn(raw_data, hyperparameters)
                    ##Save_result
                    file_path  = f'{datadir}_w{p1}_b{p2}_d{p3}_rate{p4}_unit{p5}.pkl' 
                    savedict(file_path, dict_name=r)
                    new_data = {f'{datadir}_w{p1}_b{p2}_d{p3}_rate{p4}_unit{p5}':r} 
                
                    ### Provide NEW Data Container
                    Temperature_Results.update(new_data)

# %% [markdown]
# # 4.Dew

# %%
dew_data = raw_METAR_data['dew']

# %%
### Everything is here in 1 Cell to avoid confusions. Later will automate this for batch processing.
raw_data =dew_data 
Dew_Results = {} # Container for finalized data
param_list_1 = [6,12,24]
param_list_2 = [8,16,32]
param_list_3 = [2,3,4]
param_list_4 = [0.1,0.2,0.3]
param_list_5 = [50,80]
data_id = 'set1'
datadir = f'../results/dew/dew_{data_id}'

### NO Changes down Here ###
for p1 in param_list_1:
    for p2 in param_list_2:
        for p3 in param_list_3:
            for p4 in param_list_4:
                for p5 in param_list_5:
                    print(f'>>> Starting Training for param :')
                    print(f'window: {p1}')
                    print(f'batch_size: {p2}')
                    print(f'LSTM_depth: {p3}')
                    print(f'Dropout_rate: {p4}')
                    print(f'N_unit: {p5}')
                    
                    # Specify Hyperparameters, and perform training/predictions
                    hyperparameters = {
                        'n_units' : p5,'dropout_rate' : p4, 'n_dense' : 1,
                        'n_epochs' : 100,'n_batch' : p2,'LSTM_depth' : p3,
                        'n_train' :1000,'n_test' : 200,
                        'window_size':p1, 'scaling':'MinMax'
                    }
                    r = ML.process_training_data_and_learn(raw_data, hyperparameters)
                    ##Save_result
                    file_path  = f'{datadir}_w{p1}_b{p2}_d{p3}_rate{p4}_unit{p5}.pkl' 
                    savedict(file_path, dict_name=r)
                    new_data = {f'{datadir}_w{p1}_b{p2}_d{p3}_rate{p4}_unit{p5}':r} 
                
                    ### Provide NEW Data Container
                    Dew_Results.update(new_data)
# Out:
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 50
# Epoch 1: loss = 0.05450265482068062, duration = 6.90 seconds
# Epoch 11: loss = 0.007681295275688171, duration = 1.04 seconds
# Epoch 21: loss = 0.00414268160238862, duration = 1.04 seconds
# Epoch 31: loss = 0.003136988263577223, duration = 1.08 seconds
# Epoch 41: loss = 0.002946313237771392, duration = 1.08 seconds
# Epoch 51: loss = 0.00274845864623785, duration = 0.96 seconds
# Epoch 61: loss = 0.002427485538646579, duration = 0.93 seconds
# Epoch 71: loss = 0.0024616976734250784, duration = 0.84 seconds
# Epoch 81: loss = 0.002497731475159526, duration = 0.95 seconds
# Epoch 91: loss = 0.002388467313721776, duration = 0.88 seconds
# 7/7 [==============================] - 1s 3ms/step
# The root mean squared error is 1.0043114457860005.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d2_rate0.1_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 80
# Epoch 1: loss = 0.04219906032085419, duration = 5.77 seconds
# Epoch 11: loss = 0.005618951749056578, duration = 1.15 seconds
# Epoch 21: loss = 0.0034835385158658028, duration = 1.16 seconds
# Epoch 31: loss = 0.003172125667333603, duration = 1.22 seconds
# Epoch 41: loss = 0.0027131212409585714, duration = 1.13 seconds
# Epoch 51: loss = 0.002546067815274, duration = 0.95 seconds
# Epoch 61: loss = 0.0025341634172946215, duration = 1.62 seconds
# Epoch 71: loss = 0.0023251285310834646, duration = 1.17 seconds
# Epoch 81: loss = 0.0024761331733316183, duration = 1.08 seconds
# Epoch 91: loss = 0.0024444039445370436, duration = 1.41 seconds
# 7/7 [==============================] - 1s 4ms/step
# The root mean squared error is 1.0638906587829546.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d2_rate0.1_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.2
# N_unit: 50
# Epoch 1: loss = 0.05070986971259117, duration = 7.77 seconds
# Epoch 11: loss = 0.010146638378500938, duration = 0.94 seconds
# Epoch 21: loss = 0.005965481977909803, duration = 0.94 seconds
# Epoch 31: loss = 0.004324931651353836, duration = 0.98 seconds
# Epoch 41: loss = 0.0035267723724246025, duration = 0.94 seconds
# Epoch 51: loss = 0.003151283133774996, duration = 0.89 seconds
# Epoch 61: loss = 0.003024500794708729, duration = 0.95 seconds
# Epoch 71: loss = 0.002554809907451272, duration = 1.35 seconds
# Epoch 81: loss = 0.002749224193394184, duration = 1.21 seconds
# Epoch 91: loss = 0.002584578236564994, duration = 1.42 seconds
# 7/7 [==============================] - 3s 5ms/step
# The root mean squared error is 0.9942979826253485.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d2_rate0.2_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.2
# N_unit: 80
# Epoch 1: loss = 0.03915522247552872, duration = 15.23 seconds
# Epoch 11: loss = 0.00721494946628809, duration = 2.08 seconds
# Epoch 21: loss = 0.004360446706414223, duration = 1.68 seconds
# Epoch 31: loss = 0.003546701278537512, duration = 1.53 seconds
# Epoch 41: loss = 0.0033371825702488422, duration = 2.17 seconds
# Epoch 51: loss = 0.003091261023655534, duration = 1.71 seconds
# Epoch 61: loss = 0.002583335852250457, duration = 1.32 seconds
# Epoch 71: loss = 0.002581886714324355, duration = 1.74 seconds
# Epoch 81: loss = 0.002762598218396306, duration = 2.16 seconds
# Epoch 91: loss = 0.002441938268020749, duration = 2.10 seconds
# 7/7 [==============================] - 1s 5ms/step
# The root mean squared error is 1.0263792045233116.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d2_rate0.2_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.3
# N_unit: 50
# Epoch 1: loss = 0.05879665166139603, duration = 6.71 seconds
# Epoch 11: loss = 0.01190764456987381, duration = 1.57 seconds
# Epoch 21: loss = 0.006732783280313015, duration = 1.37 seconds
# Epoch 31: loss = 0.004808344412595034, duration = 1.39 seconds
# Epoch 41: loss = 0.00456584757193923, duration = 1.26 seconds
# Epoch 51: loss = 0.003463282948359847, duration = 1.52 seconds
# Epoch 61: loss = 0.003349406411871314, duration = 1.53 seconds
# Epoch 71: loss = 0.002887045731768012, duration = 1.39 seconds
# Epoch 81: loss = 0.0033081183210015297, duration = 1.39 seconds
# Epoch 91: loss = 0.0029110671021044254, duration = 1.77 seconds
# 7/7 [==============================] - 3s 5ms/step
# The root mean squared error is 1.0894438674222577.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d2_rate0.3_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 2
# Dropout_rate: 0.3
# N_unit: 80
# Epoch 1: loss = 0.04650043696165085, duration = 14.70 seconds
# Epoch 11: loss = 0.0093814916908741, duration = 2.25 seconds
# Epoch 21: loss = 0.005338233895599842, duration = 1.28 seconds
# Epoch 31: loss = 0.004597910679876804, duration = 0.92 seconds
# Epoch 41: loss = 0.0038168933242559433, duration = 1.16 seconds
# Epoch 51: loss = 0.002953131916001439, duration = 1.56 seconds
# Epoch 61: loss = 0.003220598679035902, duration = 1.05 seconds
# Epoch 71: loss = 0.002846105955541134, duration = 1.50 seconds
# Epoch 81: loss = 0.002836375730112195, duration = 1.88 seconds
# Epoch 91: loss = 0.0026493878103792667, duration = 1.63 seconds
# 7/7 [==============================] - 3s 4ms/step
# The root mean squared error is 1.1445460771318539.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d2_rate0.3_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.1
# N_unit: 50
# Epoch 1: loss = 0.06764402240514755, duration = 18.76 seconds
# Epoch 11: loss = 0.008783034980297089, duration = 1.56 seconds
# Epoch 21: loss = 0.004254971630871296, duration = 1.78 seconds
# Epoch 31: loss = 0.0036244092043489218, duration = 1.81 seconds
# Epoch 41: loss = 0.0029973937198519707, duration = 1.78 seconds
# Epoch 51: loss = 0.0031774078961461782, duration = 1.33 seconds
# Epoch 61: loss = 0.002700404031202197, duration = 1.54 seconds
# Epoch 71: loss = 0.0024798403028398752, duration = 1.34 seconds
# Epoch 81: loss = 0.0023673789110034704, duration = 2.07 seconds
# Epoch 91: loss = 0.0021762161049991846, duration = 1.96 seconds
# 7/7 [==============================] - 3s 4ms/step
# The root mean squared error is 1.0504378144769453.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d3_rate0.1_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.1
# N_unit: 80
# Epoch 1: loss = 0.05283350870013237, duration = 20.67 seconds
# Epoch 11: loss = 0.007009546272456646, duration = 2.34 seconds
# Epoch 21: loss = 0.003753825556486845, duration = 2.29 seconds
# Epoch 31: loss = 0.003262183628976345, duration = 2.30 seconds
# Epoch 41: loss = 0.003095505526289344, duration = 2.93 seconds
# Epoch 51: loss = 0.0026567198801785707, duration = 2.22 seconds
# Epoch 61: loss = 0.0025928535033017397, duration = 2.21 seconds
# Epoch 71: loss = 0.002369408030062914, duration = 2.35 seconds
# Epoch 81: loss = 0.002180186565965414, duration = 3.16 seconds
# Epoch 91: loss = 0.0021280329674482346, duration = 2.16 seconds
# 7/7 [==============================] - 3s 6ms/step
# The root mean squared error is 1.0804253545505114.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d3_rate0.1_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.2
# N_unit: 50
# Epoch 1: loss = 0.06848062574863434, duration = 15.04 seconds
# Epoch 11: loss = 0.0121351582929492, duration = 1.35 seconds
# Epoch 21: loss = 0.00695341220125556, duration = 1.91 seconds
# Epoch 31: loss = 0.004456187132745981, duration = 1.91 seconds
# Epoch 41: loss = 0.003968423698097467, duration = 2.08 seconds
# Epoch 51: loss = 0.0033732857555150986, duration = 2.18 seconds
# Epoch 61: loss = 0.0033914868254214525, duration = 2.10 seconds
# Epoch 71: loss = 0.0030394871719181538, duration = 2.30 seconds
# Epoch 81: loss = 0.002686593448743224, duration = 2.16 seconds
# Epoch 91: loss = 0.0025118442717939615, duration = 2.03 seconds
# 7/7 [==============================] - 3s 4ms/step
# The root mean squared error is 1.231561050580462.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d3_rate0.2_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.2
# N_unit: 80
# Epoch 1: loss = 0.05727829039096832, duration = 9.44 seconds
# Epoch 11: loss = 0.00907039362937212, duration = 1.55 seconds
# Epoch 21: loss = 0.005071691703051329, duration = 1.44 seconds
# Epoch 31: loss = 0.004054876044392586, duration = 1.83 seconds
# Epoch 41: loss = 0.003224207554012537, duration = 1.95 seconds
# Epoch 51: loss = 0.003735646605491638, duration = 1.42 seconds
# Epoch 61: loss = 0.002755349036306143, duration = 1.50 seconds
# Epoch 71: loss = 0.00272591901011765, duration = 1.66 seconds
# Epoch 81: loss = 0.002743605524301529, duration = 1.49 seconds
# Epoch 91: loss = 0.002606811234727502, duration = 1.50 seconds
# 7/7 [==============================] - 2s 5ms/step
# The root mean squared error is 1.3510234710918283.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d3_rate0.2_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.3
# N_unit: 50
# Epoch 1: loss = 0.06654530018568039, duration = 9.03 seconds
# Epoch 11: loss = 0.013462486676871777, duration = 1.49 seconds
# Epoch 21: loss = 0.00791630893945694, duration = 1.29 seconds
# Epoch 31: loss = 0.005495338700711727, duration = 1.36 seconds
# Epoch 41: loss = 0.004124409984797239, duration = 1.25 seconds
# Epoch 51: loss = 0.0036020821426063776, duration = 1.28 seconds
# Epoch 61: loss = 0.0034859636798501015, duration = 1.54 seconds
# Epoch 71: loss = 0.0035958844237029552, duration = 1.18 seconds
# Epoch 81: loss = 0.0027918752748519182, duration = 1.26 seconds
# Epoch 91: loss = 0.0030170197132974863, duration = 1.35 seconds
# 7/7 [==============================] - 2s 4ms/step
# The root mean squared error is 1.306933062807356.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d3_rate0.3_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 3
# Dropout_rate: 0.3
# N_unit: 80
# Epoch 1: loss = 0.0580689013004303, duration = 8.89 seconds
# Epoch 11: loss = 0.010164919309318066, duration = 1.36 seconds
# Epoch 21: loss = 0.005751240998506546, duration = 1.41 seconds
# Epoch 31: loss = 0.004378576297312975, duration = 1.47 seconds
# Epoch 41: loss = 0.003955668769776821, duration = 1.50 seconds
# Epoch 51: loss = 0.003997406456619501, duration = 1.45 seconds
# Epoch 61: loss = 0.003252660157158971, duration = 1.50 seconds
# Epoch 71: loss = 0.0031400457955896854, duration = 1.52 seconds
# Epoch 81: loss = 0.003007204970344901, duration = 1.60 seconds
# Epoch 91: loss = 0.0026776562444865704, duration = 1.44 seconds
# 7/7 [==============================] - 2s 5ms/step
# The root mean squared error is 1.0412978757483127.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d3_rate0.3_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 4
# Dropout_rate: 0.1
# N_unit: 50
# Epoch 1: loss = 0.070852130651474, duration = 12.36 seconds
# Epoch 11: loss = 0.010569849982857704, duration = 1.46 seconds
# Epoch 21: loss = 0.005652075167745352, duration = 1.54 seconds
# Epoch 31: loss = 0.004175796639174223, duration = 1.55 seconds
# Epoch 41: loss = 0.0032630451023578644, duration = 1.69 seconds
# Epoch 51: loss = 0.003101632697507739, duration = 1.42 seconds
# Epoch 61: loss = 0.0027974392287433147, duration = 1.71 seconds
# Epoch 71: loss = 0.002650005044415593, duration = 1.44 seconds
# Epoch 81: loss = 0.0026948056183755398, duration = 1.64 seconds
# Epoch 91: loss = 0.002351311966776848, duration = 1.61 seconds
# 7/7 [==============================] - 2s 4ms/step
# The root mean squared error is 1.0076055264235062.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d4_rate0.1_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 4
# Dropout_rate: 0.1
# N_unit: 80
# Epoch 1: loss = 0.06678007543087006, duration = 10.62 seconds
# Epoch 11: loss = 0.009332103654742241, duration = 1.93 seconds
# Epoch 21: loss = 0.004215685185045004, duration = 1.61 seconds
# Epoch 31: loss = 0.003340888535603881, duration = 1.98 seconds
# Epoch 41: loss = 0.002746307523921132, duration = 1.80 seconds
# Epoch 51: loss = 0.0029056742787361145, duration = 1.92 seconds
# Epoch 61: loss = 0.002789313206449151, duration = 1.63 seconds
# Epoch 71: loss = 0.002588151954114437, duration = 1.88 seconds
# Epoch 81: loss = 0.002369530498981476, duration = 1.83 seconds
# Epoch 91: loss = 0.0025121644139289856, duration = 1.86 seconds
# 7/7 [==============================] - 2s 12ms/step
# The root mean squared error is 1.27431570995358.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d4_rate0.1_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 4
# Dropout_rate: 0.2
# N_unit: 50
# Epoch 1: loss = 0.07472794502973557, duration = 10.89 seconds
# Epoch 11: loss = 0.012902156449854374, duration = 1.57 seconds
# Epoch 21: loss = 0.007512288633733988, duration = 1.54 seconds
# Epoch 31: loss = 0.005239646416157484, duration = 1.40 seconds
# Epoch 41: loss = 0.004528633318841457, duration = 1.35 seconds
# Epoch 51: loss = 0.003940061666071415, duration = 1.53 seconds
# Epoch 61: loss = 0.003294839058071375, duration = 1.71 seconds
# Epoch 71: loss = 0.0031111976131796837, duration = 1.76 seconds
# Epoch 81: loss = 0.003081147326156497, duration = 1.59 seconds
# Epoch 91: loss = 0.0028126381803303957, duration = 1.66 seconds
# 7/7 [==============================] - 2s 5ms/step
# The root mean squared error is 1.0748138024241287.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d4_rate0.2_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 4
# Dropout_rate: 0.2
# N_unit: 80
# Epoch 1: loss = 0.065642349421978, duration = 11.38 seconds
# Epoch 11: loss = 0.009985148906707764, duration = 1.82 seconds
# Epoch 21: loss = 0.005547835025936365, duration = 1.82 seconds
# Epoch 31: loss = 0.004266766831278801, duration = 1.69 seconds
# Epoch 41: loss = 0.003629990853369236, duration = 1.67 seconds
# Epoch 51: loss = 0.003502189414575696, duration = 1.76 seconds
# Epoch 61: loss = 0.002997066592797637, duration = 1.77 seconds
# Epoch 71: loss = 0.0028924704529345036, duration = 1.92 seconds
# Epoch 81: loss = 0.0027179676108062267, duration = 1.81 seconds
# Epoch 91: loss = 0.0028801895678043365, duration = 1.72 seconds
# 7/7 [==============================] - 2s 7ms/step
# The root mean squared error is 1.1831544506371663.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d4_rate0.2_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 4
# Dropout_rate: 0.3
# N_unit: 50
# Epoch 1: loss = 0.07653144001960754, duration = 10.79 seconds
# Epoch 11: loss = 0.014006255194544792, duration = 1.56 seconds
# Epoch 21: loss = 0.009677658788859844, duration = 1.56 seconds
# Epoch 31: loss = 0.006921002641320229, duration = 1.62 seconds
# Epoch 41: loss = 0.004841692745685577, duration = 1.57 seconds
# Epoch 51: loss = 0.004477940499782562, duration = 1.37 seconds
# Epoch 61: loss = 0.0035918878857046366, duration = 1.63 seconds
# Epoch 71: loss = 0.003745460184291005, duration = 1.39 seconds
# Epoch 81: loss = 0.003405106719583273, duration = 1.74 seconds
# Epoch 91: loss = 0.0036370547022670507, duration = 1.76 seconds
# 7/7 [==============================] - 2s 5ms/step
# The root mean squared error is 1.0543438885253402.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d4_rate0.3_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 8
# LSTM_depth: 4
# Dropout_rate: 0.3
# N_unit: 80
# Epoch 1: loss = 0.06234857067465782, duration = 10.87 seconds
# Epoch 11: loss = 0.012009466998279095, duration = 1.81 seconds
# Epoch 21: loss = 0.006721794605255127, duration = 1.90 seconds
# Epoch 31: loss = 0.005389247555285692, duration = 3.48 seconds
# Epoch 41: loss = 0.004974666517227888, duration = 1.81 seconds
# Epoch 51: loss = 0.004207718186080456, duration = 1.82 seconds
# Epoch 61: loss = 0.0033747446723282337, duration = 1.99 seconds
# Epoch 71: loss = 0.0037347658071666956, duration = 1.88 seconds
# Epoch 81: loss = 0.0032432929147034883, duration = 1.73 seconds
# Epoch 91: loss = 0.0030765479896217585, duration = 1.67 seconds
# 7/7 [==============================] - 2s 6ms/step
# The root mean squared error is 1.2158080364465174.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b8_d4_rate0.3_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 16
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 50
# Epoch 1: loss = 0.11311941593885422, duration = 6.13 seconds
# Epoch 11: loss = 0.008939186111092567, duration = 0.45 seconds
# Epoch 21: loss = 0.006648710463196039, duration = 0.46 seconds
# Epoch 31: loss = 0.00480936374515295, duration = 0.53 seconds
# Epoch 41: loss = 0.0036263270303606987, duration = 0.45 seconds
# Epoch 51: loss = 0.003466640831902623, duration = 0.53 seconds
# Epoch 61: loss = 0.00296131893992424, duration = 0.47 seconds
# Epoch 71: loss = 0.0029301077593117952, duration = 0.53 seconds
# Epoch 81: loss = 0.00278275809250772, duration = 0.45 seconds
# Epoch 91: loss = 0.0027378315571695566, duration = 0.51 seconds
# 7/7 [==============================] - 1s 4ms/step
# The root mean squared error is 1.3565706662279016.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b16_d2_rate0.1_unit50.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 16
# LSTM_depth: 2
# Dropout_rate: 0.1
# N_unit: 80
# Epoch 1: loss = 0.07415421307086945, duration = 6.30 seconds
# Epoch 11: loss = 0.008307316340506077, duration = 0.72 seconds
# Epoch 21: loss = 0.004661897663027048, duration = 0.58 seconds
# Epoch 31: loss = 0.003460114588961005, duration = 0.68 seconds
# Epoch 41: loss = 0.002884238725528121, duration = 0.67 seconds
# Epoch 51: loss = 0.00309103075414896, duration = 0.70 seconds
# Epoch 61: loss = 0.0028450037352740765, duration = 0.56 seconds
# Epoch 71: loss = 0.0025525717064738274, duration = 0.70 seconds
# Epoch 81: loss = 0.002716552233323455, duration = 0.63 seconds
# Epoch 91: loss = 0.00224716542288661, duration = 0.63 seconds
# 7/7 [==============================] - 1s 6ms/step
# The root mean squared error is 1.0306552202864998.
# The data dictionary has been saved to ../results/dew/dew_set1_w6_b16_d2_rate0.1_unit80.pkl.
# >>> Starting Training for param :
# window: 6
# batch_size: 16
# LSTM_depth: 2
# Dropout_rate: 0.2
# N_unit: 50

# %% [markdown]
# # 5.Air Pressure
